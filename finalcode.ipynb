# %%
# CELL 1: Imports, Setup, and Hyperparameters

# Install necessary libraries if not already installed
# !pip install torch torchvision numpy tqdm matplotlib

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader, random_split
from tqdm import tqdm
import os
import numpy as np

# Global Settings
NUM_EPOCHS = 100          # was 10
BATCH_SIZE = 128         # was 64
LEARNING_RATE = 0.001     # keep same (good for Adam)
WEIGHT_DECAY = 5e-4       # stronger regularization
DROPOUT_RATE = 0.3        # slightly lower
VALIDATION_SPLIT = 0.1
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# CIFAR-10 Statistics
cifar10_mean = [0.4914, 0.4822, 0.4465]
cifar10_std = [0.2023, 0.1994, 0.2010]

# Model Checkpoint Path (used temporarily to save best model during each run)
MODEL_SAVE_PATH = 'best_model_cifar10_temp.pth'

# List to store results from all experiments
RESULTS_TABLE = []

print(f"Running experiments on device: {DEVICE}")
print(f"Number of Epochs set to: {NUM_EPOCHS} (Change to 100 for max accuracy)")
# Out:
# Running experiments on device: cuda
# Number of Epochs set to: 100 (Change to 100 for max accuracy)

# %%
# CELL 2: Data Preparation and Loading Functions

from torchvision import transforms, datasets
from torch.utils.data import DataLoader, random_split
from torchvision.transforms import AutoAugment, AutoAugmentPolicy

def prepare_data(use_augmentation=True):
    # Transformation for Test/Validation data (always consistent)
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(cifar10_mean, cifar10_std)
    ])
    
    # Training data transformations (with strong augmentation)
    if use_augmentation:
        print("Using Strong Data Augmentation (Crop, Flip, AutoAugment)")
        train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            AutoAugment(policy=AutoAugmentPolicy.CIFAR10),
            transforms.ToTensor(),
            transforms.Normalize(cifar10_mean, cifar10_std)
        ])
    else:
        print("Ablation: NO Data Augmentation used.")
        train_transform = test_transform  # Use simple test transform for training

    # Download and create datasets
    train_full = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
    test_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)

    # Split training data into training and validation sets
    val_size = int(len(train_full) * VALIDATION_SPLIT)
    train_size = len(train_full) - val_size
    train_dataset, val_dataset = random_split(train_full, [train_size, val_size])

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

    return train_loader, val_loader, test_loader

print("✅ Data preparation functions defined.")
# Out:
# ✅ Data preparation functions defined.

# %%
# CELL 3: Model Architecture and Setup Functions

# Your Original SimpleCNN (with configurable Dropout)
class SimpleCNN(nn.Module):
    def __init__(self, dropout_rate=0.0):
        super(SimpleCNN, self).__init__()
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # 32x32 -> 16x16

            # Block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),  # 16x16 -> 8x8

            # Block 3
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)   # 8x8 -> 4x4
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256 * 4 * 4, 512), # 4096 features
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate), # <- Configurable Dropout
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate), # <- Configurable Dropout
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

def create_resnet18_baseline():
    """Creates the ResNet-18 model for baseline comparison."""
    # Load pre-trained weights from ImageNet
    model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

    # Replace the final layer for CIFAR-10 (10 classes)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 10)
    
    # Use standard low LR for fine-tuning SOTA model
    return model, 0.0001, 'ResNet-18 (SOTA Baseline)', WEIGHT_DECAY
def create_resnet50_baseline():
    """Creates the ResNet-50 model (stronger SOTA baseline)."""
    model = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 10)
    return model, 0.0001, 'ResNet-50 (SOTA+)', WEIGHT_DECAY

def create_simplecnn_model(ablation_name, dropout_rate=DROPOUT_RATE, weight_decay=WEIGHT_DECAY, learning_rate=LEARNING_RATE):
    """Creates a SimpleCNN instance with specific ablation settings."""
    model = SimpleCNN(dropout_rate=dropout_rate)
    return model, learning_rate, ablation_name, weight_decay

print("Model architectures defined.")
# Out:
# Model architectures defined.

# %%
# CELL 4: Training and Evaluation Functions

def validate_model(model, val_loader, criterion):
    """Calculates validation loss and accuracy."""
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item() * inputs.size(0)

            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    avg_loss = total_loss / total
    accuracy = 100. * correct / total
    return avg_loss, accuracy


def run_training_experiment(model, lr, name, weight_decay, use_augmentation):
    """Runs a single training experiment with specified settings."""
    global RESULTS_TABLE
    print(f"\n--- Starting Experiment: {name} ---")

    # 1. Data Setup (Ablation Hook for Augmentation)
    train_loader, val_loader, test_loader = prepare_data(use_augmentation=use_augmentation)

    # 2. Setup Model, Loss, Optimizer, and Scheduler
    model = model.to(DEVICE)
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)  # ✅ Added label smoothing
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)  # ✅ Use CosineAnnealingLR

    best_val_accuracy = 0.0

    # 3. Training Loop
    for epoch in range(NUM_EPOCHS):
        model.train()
        train_loss = 0.0

        # Use tqdm for progress bar
        pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS} ({name})", unit="batch")

        for inputs, targets in pbar:
            inputs, targets = inputs.to(DEVICE), targets.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            pbar.set_postfix({'loss': f'{train_loss/len(train_loader):.4f}', 'LR': f'{optimizer.param_groups[0]["lr"]:.6f}'})

        # 4. Validation and Checkpointing
        val_loss, val_acc = validate_model(model, val_loader, criterion)
        scheduler.step()  # ✅ Step cosine scheduler each epoch

        # Save the best model
        if val_acc > best_val_accuracy:
            best_val_accuracy = val_acc
            torch.save(model.state_dict(), MODEL_SAVE_PATH)

    # 5. Final Test Evaluation (Load Best Model)
    model.load_state_dict(torch.load(MODEL_SAVE_PATH))
    test_loss, test_acc = validate_model(model, test_loader, criterion)

    # Store result for the final table
    RESULTS_TABLE.append({
        'Model': name, 
        'ValidationAcc': best_val_accuracy, 
        'TestAcc': test_acc
    })
    
    print(f"--- Experiment Finished: {name} ---")
    print(f"Final Test Accuracy for {name}: {test_acc:.2f}%")
    
    return best_val_accuracy, test_acc


print("Training and evaluation logic defined.")
# Out:
# Training and evaluation logic defined.

# %%
# CELL 5: Master Runner and Final Report Generation

def run_all_experiments():
    """Defines and runs all required experiments sequentially and prints the final report."""
    global RESULTS_TABLE
    RESULTS_TABLE = [] # Reset results

    # --- EXPERIMENT 1: MAIN MODEL (Full SimpleCNN) ---
    # This is your optimized 90.47% model configuration
    model_full, lr_full, name_full, wd_full = create_simplecnn_model("SimpleCNN (Main/Full)")
    run_training_experiment(model_full, lr_full, name_full, wd_full, use_augmentation=True)

    # --- EXPERIMENT 2: SOTA BASELINE (ResNet-50 for High Accuracy) ---
    model_resnet50, lr_resnet50, name_resnet50, wd_resnet50 = create_resnet50_baseline()
    run_training_experiment(model_resnet50, lr_resnet50, name_resnet50, wd_resnet50, use_augmentation=True)

    # --- EXPERIMENT 3: ABLATION 1 (No Data Augmentation) ---
    # Fulfills "Ablation on core modules" requirement
    model_no_aug, lr_no_aug, name_no_aug, wd_no_aug = create_simplecnn_model("Ablation 1 (No Augmentation)")
    run_training_experiment(model_no_aug, lr_no_aug, name_no_aug, wd_no_aug, use_augmentation=False)

    # --- EXPERIMENT 4: ABLATION 2 (No Dropout) ---
    # Fulfills "Ablation on hyper-parameters" requirement
    model_no_dropout, lr_no_dropout, name_no_dropout, wd_no_dropout = create_simplecnn_model("Ablation 2 (No Dropout)", dropout_rate=0.0)
    run_training_experiment(model_no_dropout, lr_no_dropout, name_no_dropout, wd_no_dropout, use_augmentation=True)

    # --- EXPERIMENT 5: ABLATION 3 (No L2 Regularization / Weight Decay) ---
    # Fulfills "Ablation on hyper-parameters" requirement
    model_no_l2, lr_no_l2, name_no_l2, wd_no_l2 = create_simplecnn_model("Ablation 3 (No L2 Decay)", weight_decay=0.0)
    run_training_experiment(model_no_l2, lr_no_l2, name_no_l2, wd_no_l2, use_augmentation=True)

    # --- FINAL REPORT GENERATION ---
    print("\n\n" + "="*70)
    print("FINAL EXPERIMENTAL RESULTS SUMMARY FOR PROJECT REPORT")
    print("="*70)

    # Find the result for the Main Model to use as the baseline for the Ablation table
    main_model_result = next(res for res in RESULTS_TABLE if 'Main' in res['Model'])
    
    # 1. Quantitative Comparison (Baseline) Table
    print("\n\n--- Table 1: Quantitative Comparison (Baseline) ---")
    print("{:<35} {:<15} {:<15}".format("Model", "Test Acc. (%)", "Type"))
    print("-" * 65)
    for res in RESULTS_TABLE:
        model_type = "Custom CNN (Ours)" if 'SimpleCNN' in res['Model'] else "SOTA (ResNet-18)"
        if 'Main' in res['Model'] or 'ResNet-18' in res['Model']:
            print("{:<35} {:<15.2f} {:<15}".format(res['Model'], res['TestAcc'], model_type))


    # 2. Ablation Study Table
    print("\n\n--- Table 2: Ablation Study (3 Groups on SimpleCNN) ---")
    print("{:<35} {:<20} {:<15}".format("Experiment", "Configuration", "Test Acc. (%)"))
    print("-" * 70)
    
    # Print Main Model first for context
    print("{:<35} {:<20} {:<15.2f}".format(
        "Main Model (Best)",
        "Full Features",
        main_model_result['TestAcc']
    ))
    
    # Print Ablations
    for res in RESULTS_TABLE:
        if 'Ablation' in res['Model']:
            config = res['Model'].split('(')[-1].replace(')', '')
            print("{:<35} {:<20} {:<15.2f}".format(
                res['Model'],
                f"No {config}",
                res['TestAcc']
            ))


    print("\nAll required experiments are complete.")
    
    # Clean up temporary saved model file
    if os.path.exists(MODEL_SAVE_PATH):
        os.remove(MODEL_SAVE_PATH)

# Execute the master function to start the entire process
if __name__ == '__main__':
    run_all_experiments()

print("Master execution function defined. Run this cell to start all 5 experiments.")
# Out:
# --- Starting Experiment: SimpleCNN (Main/Full) ---
# Using Strong Data Augmentation (Crop, Flip, AutoAugment)
# Epoch 1/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.97batch/s, loss=1.8123, LR=0.001000]
# Epoch 2/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.88batch/s, loss=1.5284, LR=0.001000]
# Epoch 3/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.12batch/s, loss=1.4405, LR=0.000999]
# Epoch 4/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.49batch/s, loss=1.3950, LR=0.000998]
# Epoch 5/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.79batch/s, loss=1.3485, LR=0.000996]
# Epoch 6/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.59batch/s, loss=1.3209, LR=0.000994]
# Epoch 7/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.77batch/s, loss=1.2964, LR=0.000991]
# Epoch 8/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.85batch/s, loss=1.2735, LR=0.000988]
# Epoch 9/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.69batch/s, loss=1.2533, LR=0.000984]
# Epoch 10/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.40batch/s, loss=1.2321, LR=0.000980]
# Epoch 11/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.72batch/s, loss=1.2176, LR=0.000976]
# Epoch 12/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.29batch/s, loss=1.2005, LR=0.000970]
# Epoch 13/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.62batch/s, loss=1.1882, LR=0.000965]
# Epoch 14/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.29batch/s, loss=1.1757, LR=0.000959]
# Epoch 15/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.47batch/s, loss=1.1686, LR=0.000952]
# Epoch 16/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.22batch/s, loss=1.1573, LR=0.000946]
# Epoch 17/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.84batch/s, loss=1.1494, LR=0.000938]
# Epoch 18/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.02batch/s, loss=1.1404, LR=0.000930]
# Epoch 19/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.42batch/s, loss=1.1320, LR=0.000922]
# Epoch 20/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.83batch/s, loss=1.1247, LR=0.000914]
# Epoch 21/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.22batch/s, loss=1.1222, LR=0.000905]
# Epoch 22/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.76batch/s, loss=1.1200, LR=0.000895]
# Epoch 23/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.66batch/s, loss=1.1102, LR=0.000885]
# Epoch 24/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.74batch/s, loss=1.1057, LR=0.000875]
# Epoch 25/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.39batch/s, loss=1.1025, LR=0.000864]
# Epoch 26/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.16batch/s, loss=1.0934, LR=0.000854]
# Epoch 27/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.24batch/s, loss=1.0917, LR=0.000842]
# Epoch 28/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.24batch/s, loss=1.0792, LR=0.000831]
# Epoch 29/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.72batch/s, loss=1.0787, LR=0.000819]
# Epoch 30/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.55batch/s, loss=1.0699, LR=0.000806]
# Epoch 31/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.31batch/s, loss=1.0701, LR=0.000794]
# Epoch 32/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.44batch/s, loss=1.0665, LR=0.000781]
# Epoch 33/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.16batch/s, loss=1.0610, LR=0.000768]
# Epoch 34/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.97batch/s, loss=1.0573, LR=0.000755]
# Epoch 35/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.33batch/s, loss=1.0518, LR=0.000741]
# Epoch 36/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.07batch/s, loss=1.0476, LR=0.000727]
# Epoch 37/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.43batch/s, loss=1.0435, LR=0.000713]
# Epoch 38/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.39batch/s, loss=1.0391, LR=0.000699]
# Epoch 39/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.06batch/s, loss=1.0338, LR=0.000684]
# Epoch 40/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.73batch/s, loss=1.0365, LR=0.000669]
# Epoch 41/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.08batch/s, loss=1.0232, LR=0.000655]
# Epoch 42/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.52batch/s, loss=1.0309, LR=0.000639]
# Epoch 43/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.18batch/s, loss=1.0141, LR=0.000624]
# Epoch 44/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.58batch/s, loss=1.0193, LR=0.000609]
# Epoch 45/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.36batch/s, loss=1.0082, LR=0.000594]
# Epoch 46/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.24batch/s, loss=1.0097, LR=0.000578]
# Epoch 47/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.11batch/s, loss=0.9987, LR=0.000563]
# Epoch 48/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.68batch/s, loss=0.9971, LR=0.000547]
# Epoch 49/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.57batch/s, loss=0.9937, LR=0.000531]
# Epoch 50/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.15batch/s, loss=0.9858, LR=0.000516]
# Epoch 51/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.03batch/s, loss=0.9852, LR=0.000500]
# Epoch 52/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.25batch/s, loss=0.9755, LR=0.000484]
# Epoch 53/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:15<00:00, 22.47batch/s, loss=0.9760, LR=0.000469]
# Epoch 54/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.76batch/s, loss=0.9705, LR=0.000453]
# Epoch 55/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.89batch/s, loss=0.9640, LR=0.000437]
# Epoch 56/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.33batch/s, loss=0.9608, LR=0.000422]
# Epoch 57/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.72batch/s, loss=0.9609, LR=0.000406]
# Epoch 58/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.33batch/s, loss=0.9571, LR=0.000391]
# Epoch 59/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.60batch/s, loss=0.9474, LR=0.000376]
# Epoch 60/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.38batch/s, loss=0.9475, LR=0.000361]
# Epoch 61/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 19.93batch/s, loss=0.9409, LR=0.000345]
# Epoch 62/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.89batch/s, loss=0.9355, LR=0.000331]
# Epoch 63/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.31batch/s, loss=0.9263, LR=0.000316]
# Epoch 64/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.62batch/s, loss=0.9238, LR=0.000301]
# Epoch 65/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.59batch/s, loss=0.9195, LR=0.000287]
# Epoch 66/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.78batch/s, loss=0.9098, LR=0.000273]
# Epoch 67/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 19.90batch/s, loss=0.9065, LR=0.000259]
# Epoch 68/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.74batch/s, loss=0.9023, LR=0.000245]
# Epoch 69/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.27batch/s, loss=0.8966, LR=0.000232]
# Epoch 70/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.68batch/s, loss=0.8938, LR=0.000219]
# Epoch 71/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.43batch/s, loss=0.8917, LR=0.000206]
# Epoch 72/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 19.88batch/s, loss=0.8907, LR=0.000194]
# Epoch 73/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.75batch/s, loss=0.8831, LR=0.000181]
# Epoch 74/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.63batch/s, loss=0.8715, LR=0.000169]
# Epoch 75/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.89batch/s, loss=0.8755, LR=0.000158]
# Epoch 76/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 19.97batch/s, loss=0.8686, LR=0.000146]
# Epoch 77/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.58batch/s, loss=0.8630, LR=0.000136]
# Epoch 78/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.48batch/s, loss=0.8560, LR=0.000125]
# Epoch 79/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.82batch/s, loss=0.8542, LR=0.000115]
# Epoch 80/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.17batch/s, loss=0.8543, LR=0.000105]
# Epoch 81/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.27batch/s, loss=0.8446, LR=0.000095]
# Epoch 82/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.64batch/s, loss=0.8458, LR=0.000086]
# Epoch 83/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.33batch/s, loss=0.8444, LR=0.000078]
# Epoch 84/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.33batch/s, loss=0.8354, LR=0.000070]
# Epoch 85/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.07batch/s, loss=0.8337, LR=0.000062]
# Epoch 86/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.43batch/s, loss=0.8301, LR=0.000054]
# Epoch 87/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.62batch/s, loss=0.8260, LR=0.000048]
# Epoch 88/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.05batch/s, loss=0.8237, LR=0.000041]
# Epoch 89/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.67batch/s, loss=0.8243, LR=0.000035]
# Epoch 90/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.87batch/s, loss=0.8235, LR=0.000030]
# Epoch 91/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.82batch/s, loss=0.8172, LR=0.000024]
# Epoch 92/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.53batch/s, loss=0.8213, LR=0.000020]
# Epoch 93/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.24batch/s, loss=0.8186, LR=0.000016]
# Epoch 94/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.68batch/s, loss=0.8146, LR=0.000012]
# Epoch 95/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.53batch/s, loss=0.8150, LR=0.000009]
# Epoch 96/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.10batch/s, loss=0.8135, LR=0.000006]
# Epoch 97/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:17<00:00, 20.32batch/s, loss=0.8165, LR=0.000004]
# Epoch 98/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.31batch/s, loss=0.8103, LR=0.000002]
# Epoch 99/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 20.96batch/s, loss=0.8095, LR=0.000001]
# Epoch 100/100 (SimpleCNN (Main/Full)): 100%|██████████| 352/352 [00:16<00:00, 21.26batch/s, loss=0.8093, LR=0.000000]
# --- Experiment Finished: SimpleCNN (Main/Full) ---
# Final Test Accuracy for SimpleCNN (Main/Full): 90.31%
#
# --- Starting Experiment: ResNet-50 (SOTA+) ---
# Using Strong Data Augmentation (Crop, Flip, AutoAugment)
# Epoch 1/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.32batch/s, loss=1.5529, LR=0.000100]
# Epoch 2/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.71batch/s, loss=1.2209, LR=0.000100]
# Epoch 3/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.79batch/s, loss=1.1308, LR=0.000100]
# Epoch 4/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.02batch/s, loss=1.0732, LR=0.000100]
# Epoch 5/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.48batch/s, loss=1.0307, LR=0.000100]
# Epoch 6/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.11batch/s, loss=1.0051, LR=0.000099]
# Epoch 7/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.69batch/s, loss=0.9887, LR=0.000099]
# Epoch 8/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.83batch/s, loss=0.9613, LR=0.000099]
# Epoch 9/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.55batch/s, loss=0.9481, LR=0.000098]
# Epoch 10/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.90batch/s, loss=0.9334, LR=0.000098]
# Epoch 11/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.34batch/s, loss=0.9198, LR=0.000098]
# Epoch 12/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.50batch/s, loss=0.9138, LR=0.000097]
# Epoch 13/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.90batch/s, loss=0.8991, LR=0.000096]
# Epoch 14/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.39batch/s, loss=0.8866, LR=0.000096]
# Epoch 15/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.82batch/s, loss=0.8816, LR=0.000095]
# Epoch 16/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.41batch/s, loss=0.8728, LR=0.000095]
# Epoch 17/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.68batch/s, loss=0.8668, LR=0.000094]
# Epoch 18/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.60batch/s, loss=0.8576, LR=0.000093]
# Epoch 19/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.62batch/s, loss=0.8511, LR=0.000092]
# Epoch 20/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.20batch/s, loss=0.8466, LR=0.000091]
# Epoch 21/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.26batch/s, loss=0.8424, LR=0.000090]
# Epoch 22/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:19<00:00, 18.08batch/s, loss=0.8359, LR=0.000090]
# Epoch 23/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:18<00:00, 19.30batch/s, loss=0.8250, LR=0.000089]
# Epoch 24/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.99batch/s, loss=0.8211, LR=0.000088]
# Epoch 25/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.07batch/s, loss=0.8144, LR=0.000086]
# Epoch 26/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.42batch/s, loss=0.8084, LR=0.000085]
# Epoch 27/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.77batch/s, loss=0.8047, LR=0.000084]
# Epoch 28/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.23batch/s, loss=0.8026, LR=0.000083]
# Epoch 29/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:18<00:00, 18.78batch/s, loss=0.8009, LR=0.000082]
# Epoch 30/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.98batch/s, loss=0.7889, LR=0.000081]
# Epoch 31/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.91batch/s, loss=0.7893, LR=0.000079]
# Epoch 32/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.88batch/s, loss=0.7884, LR=0.000078]
# Epoch 33/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.88batch/s, loss=0.7794, LR=0.000077]
# Epoch 34/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.31batch/s, loss=0.7768, LR=0.000075]
# Epoch 35/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.86batch/s, loss=0.7748, LR=0.000074]
# Epoch 36/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.32batch/s, loss=0.7710, LR=0.000073]
# Epoch 37/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.91batch/s, loss=0.7630, LR=0.000071]
# Epoch 38/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.64batch/s, loss=0.7551, LR=0.000070]
# Epoch 39/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.96batch/s, loss=0.7615, LR=0.000068]
# Epoch 40/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.26batch/s, loss=0.7539, LR=0.000067]
# Epoch 41/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 21.05batch/s, loss=0.7457, LR=0.000065]
# Epoch 42/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.37batch/s, loss=0.7458, LR=0.000064]
# Epoch 43/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.98batch/s, loss=0.7479, LR=0.000062]
# Epoch 44/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.25batch/s, loss=0.7355, LR=0.000061]
# Epoch 45/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.83batch/s, loss=0.7380, LR=0.000059]
# Epoch 46/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.22batch/s, loss=0.7267, LR=0.000058]
# Epoch 47/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.97batch/s, loss=0.7282, LR=0.000056]
# Epoch 48/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.49batch/s, loss=0.7268, LR=0.000055]
# Epoch 49/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.79batch/s, loss=0.7221, LR=0.000053]
# Epoch 50/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.86batch/s, loss=0.7193, LR=0.000052]
# Epoch 51/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 21.09batch/s, loss=0.7142, LR=0.000050]
# Epoch 52/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.39batch/s, loss=0.7137, LR=0.000048]
# Epoch 53/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.76batch/s, loss=0.7067, LR=0.000047]
# Epoch 54/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.80batch/s, loss=0.7007, LR=0.000045]
# Epoch 55/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.87batch/s, loss=0.7055, LR=0.000044]
# Epoch 56/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.65batch/s, loss=0.7003, LR=0.000042]
# Epoch 57/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 21.08batch/s, loss=0.6929, LR=0.000041]
# Epoch 58/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.83batch/s, loss=0.6942, LR=0.000039]
# Epoch 59/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.95batch/s, loss=0.6903, LR=0.000038]
# Epoch 60/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.35batch/s, loss=0.6899, LR=0.000036]
# Epoch 61/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.56batch/s, loss=0.6838, LR=0.000035]
# Epoch 62/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.71batch/s, loss=0.6816, LR=0.000033]
# Epoch 63/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.93batch/s, loss=0.6781, LR=0.000032]
# Epoch 64/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.84batch/s, loss=0.6751, LR=0.000030]
# Epoch 65/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.72batch/s, loss=0.6744, LR=0.000029]
# Epoch 66/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.84batch/s, loss=0.6700, LR=0.000027]
# Epoch 67/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.79batch/s, loss=0.6681, LR=0.000026]
# Epoch 68/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.77batch/s, loss=0.6701, LR=0.000025]
# Epoch 69/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.00batch/s, loss=0.6691, LR=0.000023]
# Epoch 70/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.60batch/s, loss=0.6637, LR=0.000022]
# Epoch 71/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.24batch/s, loss=0.6652, LR=0.000021]
# Epoch 72/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.90batch/s, loss=0.6552, LR=0.000019]
# Epoch 73/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.30batch/s, loss=0.6561, LR=0.000018]
# Epoch 74/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.97batch/s, loss=0.6509, LR=0.000017]
# Epoch 75/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.88batch/s, loss=0.6488, LR=0.000016]
# Epoch 76/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.74batch/s, loss=0.6504, LR=0.000015]
# Epoch 77/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.47batch/s, loss=0.6522, LR=0.000014]
# Epoch 78/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.77batch/s, loss=0.6461, LR=0.000012]
# Epoch 79/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.64batch/s, loss=0.6440, LR=0.000011]
# Epoch 80/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.75batch/s, loss=0.6472, LR=0.000010]
# Epoch 81/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.57batch/s, loss=0.6440, LR=0.000010]
# Epoch 82/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.72batch/s, loss=0.6413, LR=0.000009]
# Epoch 83/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:16<00:00, 20.86batch/s, loss=0.6400, LR=0.000008]
# Epoch 84/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.66batch/s, loss=0.6414, LR=0.000007]
# Epoch 85/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.68batch/s, loss=0.6381, LR=0.000006]
# Epoch 86/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.55batch/s, loss=0.6374, LR=0.000005]
# Epoch 87/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.28batch/s, loss=0.6333, LR=0.000005]
# Epoch 88/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:18<00:00, 19.40batch/s, loss=0.6362, LR=0.000004]
# Epoch 89/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.27batch/s, loss=0.6339, LR=0.000004]
# Epoch 90/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.02batch/s, loss=0.6310, LR=0.000003]
# Epoch 91/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.37batch/s, loss=0.6299, LR=0.000002]
# Epoch 92/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.49batch/s, loss=0.6283, LR=0.000002]
# Epoch 93/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.63batch/s, loss=0.6339, LR=0.000002]
# Epoch 94/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 20.32batch/s, loss=0.6324, LR=0.000001]
# Epoch 95/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.96batch/s, loss=0.6318, LR=0.000001]
# Epoch 96/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:18<00:00, 19.42batch/s, loss=0.6318, LR=0.000001]
# Epoch 97/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:18<00:00, 18.98batch/s, loss=0.6333, LR=0.000000]
# Epoch 98/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.72batch/s, loss=0.6272, LR=0.000000]
# Epoch 99/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.67batch/s, loss=0.6314, LR=0.000000]
# Epoch 100/100 (ResNet-50 (SOTA+)): 100%|██████████| 352/352 [00:17<00:00, 19.90batch/s, loss=0.6292, LR=0.000000]
# --- Experiment Finished: ResNet-50 (SOTA+) ---
# Final Test Accuracy for ResNet-50 (SOTA+): 90.66%
#
# --- Starting Experiment: Ablation 1 (No Augmentation) ---
# Ablation: NO Data Augmentation used.
# Epoch 1/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.89batch/s, loss=1.4010, LR=0.001000]
# Epoch 2/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.85batch/s, loss=1.1237, LR=0.001000]
# Epoch 3/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.84batch/s, loss=1.0231, LR=0.000999]
# Epoch 4/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.02batch/s, loss=0.9594, LR=0.000998]
# Epoch 5/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.70batch/s, loss=0.9043, LR=0.000996]
# Epoch 6/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.73batch/s, loss=0.8584, LR=0.000994]
# Epoch 7/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.76batch/s, loss=0.8212, LR=0.000991]
# Epoch 8/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.75batch/s, loss=0.7858, LR=0.000988]
# Epoch 9/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.25batch/s, loss=0.7523, LR=0.000984]
# Epoch 10/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.15batch/s, loss=0.7309, LR=0.000980]
# Epoch 11/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.13batch/s, loss=0.7091, LR=0.000976]
# Epoch 12/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.00batch/s, loss=0.6943, LR=0.000970]
# Epoch 13/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.16batch/s, loss=0.6716, LR=0.000965]
# Epoch 14/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.98batch/s, loss=0.6692, LR=0.000959]
# Epoch 15/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.73batch/s, loss=0.6597, LR=0.000952]
# Epoch 16/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.91batch/s, loss=0.6536, LR=0.000946]
# Epoch 17/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.30batch/s, loss=0.6484, LR=0.000938]
# Epoch 18/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.74batch/s, loss=0.6418, LR=0.000930]
# Epoch 19/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.12batch/s, loss=0.6339, LR=0.000922]
# Epoch 20/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.56batch/s, loss=0.6304, LR=0.000914]
# Epoch 21/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.82batch/s, loss=0.6298, LR=0.000905]
# Epoch 22/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.57batch/s, loss=0.6233, LR=0.000895]
# Epoch 23/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.53batch/s, loss=0.6191, LR=0.000885]
# Epoch 24/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.74batch/s, loss=0.6147, LR=0.000875]
# Epoch 25/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.29batch/s, loss=0.6164, LR=0.000864]
# Epoch 26/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.54batch/s, loss=0.6111, LR=0.000854]
# Epoch 27/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 37.06batch/s, loss=0.6050, LR=0.000842]
# Epoch 28/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 37.00batch/s, loss=0.6017, LR=0.000831]
# Epoch 29/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.32batch/s, loss=0.5972, LR=0.000819]
# Epoch 30/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.18batch/s, loss=0.5978, LR=0.000806]
# Epoch 31/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.56batch/s, loss=0.6007, LR=0.000794]
# Epoch 32/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.15batch/s, loss=0.5957, LR=0.000781]
# Epoch 33/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.90batch/s, loss=0.5886, LR=0.000768]
# Epoch 34/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.89batch/s, loss=0.5880, LR=0.000755]
# Epoch 35/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.51batch/s, loss=0.5878, LR=0.000741]
# Epoch 36/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.37batch/s, loss=0.5930, LR=0.000727]
# Epoch 37/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.08batch/s, loss=0.5790, LR=0.000713]
# Epoch 38/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.92batch/s, loss=0.5748, LR=0.000699]
# Epoch 39/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 35.08batch/s, loss=0.5763, LR=0.000684]
# Epoch 40/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.64batch/s, loss=0.5742, LR=0.000669]
# Epoch 41/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.75batch/s, loss=0.5755, LR=0.000655]
# Epoch 42/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.97batch/s, loss=0.5734, LR=0.000639]
# Epoch 43/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.61batch/s, loss=0.5688, LR=0.000624]
# Epoch 44/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.26batch/s, loss=0.5632, LR=0.000609]
# Epoch 45/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.12batch/s, loss=0.5588, LR=0.000594]
# Epoch 46/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.76batch/s, loss=0.5642, LR=0.000578]
# Epoch 47/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.89batch/s, loss=0.5629, LR=0.000563]
# Epoch 48/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.44batch/s, loss=0.5535, LR=0.000547]
# Epoch 49/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.24batch/s, loss=0.5515, LR=0.000531]
# Epoch 50/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.87batch/s, loss=0.5515, LR=0.000516]
# Epoch 51/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 35.02batch/s, loss=0.5538, LR=0.000500]
# Epoch 52/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.75batch/s, loss=0.5502, LR=0.000484]
# Epoch 53/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.82batch/s, loss=0.5484, LR=0.000469]
# Epoch 54/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.69batch/s, loss=0.5449, LR=0.000453]
# Epoch 55/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.28batch/s, loss=0.5412, LR=0.000437]
# Epoch 56/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.07batch/s, loss=0.5381, LR=0.000422]
# Epoch 57/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:11<00:00, 31.10batch/s, loss=0.5406, LR=0.000406]
# Epoch 58/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.85batch/s, loss=0.5394, LR=0.000391]
# Epoch 59/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 32.97batch/s, loss=0.5396, LR=0.000376]
# Epoch 60/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.23batch/s, loss=0.5334, LR=0.000361]
# Epoch 61/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.42batch/s, loss=0.5310, LR=0.000345]
# Epoch 62/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.79batch/s, loss=0.5288, LR=0.000331]
# Epoch 63/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.87batch/s, loss=0.5289, LR=0.000316]
# Epoch 64/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.55batch/s, loss=0.5292, LR=0.000301]
# Epoch 65/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.28batch/s, loss=0.5260, LR=0.000287]
# Epoch 66/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.33batch/s, loss=0.5267, LR=0.000273]
# Epoch 67/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 32.38batch/s, loss=0.5244, LR=0.000259]
# Epoch 68/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.26batch/s, loss=0.5214, LR=0.000245]
# Epoch 69/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.20batch/s, loss=0.5187, LR=0.000232]
# Epoch 70/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.31batch/s, loss=0.5183, LR=0.000219]
# Epoch 71/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.25batch/s, loss=0.5176, LR=0.000206]
# Epoch 72/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.81batch/s, loss=0.5154, LR=0.000194]
# Epoch 73/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.50batch/s, loss=0.5159, LR=0.000181]
# Epoch 74/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 37.03batch/s, loss=0.5164, LR=0.000169]
# Epoch 75/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.24batch/s, loss=0.5166, LR=0.000158]
# Epoch 76/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.82batch/s, loss=0.5148, LR=0.000146]
# Epoch 77/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.48batch/s, loss=0.5129, LR=0.000136]
# Epoch 78/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 32.96batch/s, loss=0.5118, LR=0.000125]
# Epoch 79/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 32.43batch/s, loss=0.5112, LR=0.000115]
# Epoch 80/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.35batch/s, loss=0.5107, LR=0.000105]
# Epoch 81/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.81batch/s, loss=0.5102, LR=0.000095]
# Epoch 82/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.07batch/s, loss=0.5099, LR=0.000086]
# Epoch 83/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 35.14batch/s, loss=0.5094, LR=0.000078]
# Epoch 84/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.92batch/s, loss=0.5089, LR=0.000070]
# Epoch 85/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.70batch/s, loss=0.5086, LR=0.000062]
# Epoch 86/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 33.48batch/s, loss=0.5083, LR=0.000054]
# Epoch 87/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.71batch/s, loss=0.5081, LR=0.000048]
# Epoch 88/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.56batch/s, loss=0.5077, LR=0.000041]
# Epoch 89/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.88batch/s, loss=0.5074, LR=0.000035]
# Epoch 90/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.67batch/s, loss=0.5074, LR=0.000030]
# Epoch 91/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.88batch/s, loss=0.5070, LR=0.000024]
# Epoch 92/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.82batch/s, loss=0.5068, LR=0.000020]
# Epoch 93/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.24batch/s, loss=0.5065, LR=0.000016]
# Epoch 94/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 37.20batch/s, loss=0.5066, LR=0.000012]
# Epoch 95/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 37.15batch/s, loss=0.5064, LR=0.000009]
# Epoch 96/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.73batch/s, loss=0.5063, LR=0.000006]
# Epoch 97/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:10<00:00, 34.66batch/s, loss=0.5063, LR=0.000004]
# Epoch 98/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.49batch/s, loss=0.5061, LR=0.000002]
# Epoch 99/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 35.56batch/s, loss=0.5064, LR=0.000001]
# Epoch 100/100 (Ablation 1 (No Augmentation)): 100%|██████████| 352/352 [00:09<00:00, 36.73batch/s, loss=0.5061, LR=0.000000]
# --- Experiment Finished: Ablation 1 (No Augmentation) ---
# Final Test Accuracy for Ablation 1 (No Augmentation): 80.81%
#
# --- Starting Experiment: Ablation 2 (No Dropout) ---
# Using Strong Data Augmentation (Crop, Flip, AutoAugment)
# Epoch 1/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.67batch/s, loss=1.7577, LR=0.001000]
# Epoch 2/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.11batch/s, loss=1.4907, LR=0.001000]
# Epoch 3/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.09batch/s, loss=1.3979, LR=0.000999]
# Epoch 4/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.77batch/s, loss=1.3444, LR=0.000998]
# Epoch 5/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.41batch/s, loss=1.3074, LR=0.000996]
# Epoch 6/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.43batch/s, loss=1.2805, LR=0.000994]
# Epoch 7/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.81batch/s, loss=1.2615, LR=0.000991]
# Epoch 8/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.26batch/s, loss=1.2317, LR=0.000988]
# Epoch 9/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.41batch/s, loss=1.2195, LR=0.000984]
# Epoch 10/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.38batch/s, loss=1.1987, LR=0.000980]
# Epoch 11/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.89batch/s, loss=1.1812, LR=0.000976]
# Epoch 12/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.12batch/s, loss=1.1669, LR=0.000970]
# Epoch 13/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.07batch/s, loss=1.1556, LR=0.000965]
# Epoch 14/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.07batch/s, loss=1.1478, LR=0.000959]
# Epoch 15/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.78batch/s, loss=1.1376, LR=0.000952]
# Epoch 16/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.71batch/s, loss=1.1282, LR=0.000946]
# Epoch 17/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.55batch/s, loss=1.1149, LR=0.000938]
# Epoch 18/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.56batch/s, loss=1.1055, LR=0.000930]
# Epoch 19/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.40batch/s, loss=1.0998, LR=0.000922]
# Epoch 20/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.68batch/s, loss=1.0928, LR=0.000914]
# Epoch 21/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.39batch/s, loss=1.0874, LR=0.000905]
# Epoch 22/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.76batch/s, loss=1.0790, LR=0.000895]
# Epoch 23/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.22batch/s, loss=1.0737, LR=0.000885]
# Epoch 24/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.39batch/s, loss=1.0654, LR=0.000875]
# Epoch 25/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.36batch/s, loss=1.0665, LR=0.000864]
# Epoch 26/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.33batch/s, loss=1.0560, LR=0.000854]
# Epoch 27/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.91batch/s, loss=1.0479, LR=0.000842]
# Epoch 28/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.44batch/s, loss=1.0523, LR=0.000831]
# Epoch 29/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.57batch/s, loss=1.0452, LR=0.000819]
# Epoch 30/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.00batch/s, loss=1.0439, LR=0.000806]
# Epoch 31/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.41batch/s, loss=1.0347, LR=0.000794]
# Epoch 32/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.62batch/s, loss=1.0299, LR=0.000781]
# Epoch 33/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.77batch/s, loss=1.0254, LR=0.000768]
# Epoch 34/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.19batch/s, loss=1.0240, LR=0.000755]
# Epoch 35/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.17batch/s, loss=1.0203, LR=0.000741]
# Epoch 36/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.30batch/s, loss=1.0106, LR=0.000727]
# Epoch 37/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.97batch/s, loss=1.0084, LR=0.000713]
# Epoch 38/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.50batch/s, loss=1.0020, LR=0.000699]
# Epoch 39/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.10batch/s, loss=0.9983, LR=0.000684]
# Epoch 40/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.96batch/s, loss=0.9931, LR=0.000669]
# Epoch 41/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.18batch/s, loss=0.9945, LR=0.000655]
# Epoch 42/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.16batch/s, loss=0.9849, LR=0.000639]
# Epoch 43/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.90batch/s, loss=0.9784, LR=0.000624]
# Epoch 44/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.23batch/s, loss=0.9774, LR=0.000609]
# Epoch 45/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.24batch/s, loss=0.9768, LR=0.000594]
# Epoch 46/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.66batch/s, loss=0.9708, LR=0.000578]
# Epoch 47/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.35batch/s, loss=0.9649, LR=0.000563]
# Epoch 48/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.79batch/s, loss=0.9579, LR=0.000547]
# Epoch 49/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.93batch/s, loss=0.9524, LR=0.000531]
# Epoch 50/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.20batch/s, loss=0.9532, LR=0.000516]
# Epoch 51/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.60batch/s, loss=0.9465, LR=0.000500]
# Epoch 52/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.70batch/s, loss=0.9461, LR=0.000484]
# Epoch 53/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.86batch/s, loss=0.9423, LR=0.000469]
# Epoch 54/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.75batch/s, loss=0.9346, LR=0.000453]
# Epoch 55/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.31batch/s, loss=0.9308, LR=0.000437]
# Epoch 56/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.56batch/s, loss=0.9243, LR=0.000422]
# Epoch 57/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.28batch/s, loss=0.9176, LR=0.000406]
# Epoch 58/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.78batch/s, loss=0.9175, LR=0.000391]
# Epoch 59/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.36batch/s, loss=0.9075, LR=0.000376]
# Epoch 60/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.02batch/s, loss=0.9107, LR=0.000361]
# Epoch 61/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.01batch/s, loss=0.9002, LR=0.000345]
# Epoch 62/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.36batch/s, loss=0.8969, LR=0.000331]
# Epoch 63/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.86batch/s, loss=0.8962, LR=0.000316]
# Epoch 64/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.08batch/s, loss=0.8893, LR=0.000301]
# Epoch 65/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.37batch/s, loss=0.8782, LR=0.000287]
# Epoch 66/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.61batch/s, loss=0.8805, LR=0.000273]
# Epoch 67/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.16batch/s, loss=0.8747, LR=0.000259]
# Epoch 68/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.37batch/s, loss=0.8723, LR=0.000245]
# Epoch 69/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.05batch/s, loss=0.8647, LR=0.000232]
# Epoch 70/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.69batch/s, loss=0.8616, LR=0.000219]
# Epoch 71/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.55batch/s, loss=0.8597, LR=0.000206]
# Epoch 72/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.85batch/s, loss=0.8555, LR=0.000194]
# Epoch 73/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.97batch/s, loss=0.8508, LR=0.000181]
# Epoch 74/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.12batch/s, loss=0.8463, LR=0.000169]
# Epoch 75/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.88batch/s, loss=0.8408, LR=0.000158]
# Epoch 76/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.07batch/s, loss=0.8383, LR=0.000146]
# Epoch 77/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.24batch/s, loss=0.8316, LR=0.000136]
# Epoch 78/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.31batch/s, loss=0.8254, LR=0.000125]
# Epoch 79/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.82batch/s, loss=0.8232, LR=0.000115]
# Epoch 80/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.02batch/s, loss=0.8188, LR=0.000105]
# Epoch 81/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.00batch/s, loss=0.8175, LR=0.000095]
# Epoch 82/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.58batch/s, loss=0.8134, LR=0.000086]
# Epoch 83/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.16batch/s, loss=0.8098, LR=0.000078]
# Epoch 84/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.46batch/s, loss=0.8075, LR=0.000070]
# Epoch 85/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.44batch/s, loss=0.8085, LR=0.000062]
# Epoch 86/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.43batch/s, loss=0.8046, LR=0.000054]
# Epoch 87/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.83batch/s, loss=0.7968, LR=0.000048]
# Epoch 88/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.73batch/s, loss=0.7993, LR=0.000041]
# Epoch 89/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.57batch/s, loss=0.7952, LR=0.000035]
# Epoch 90/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:15<00:00, 22.07batch/s, loss=0.7930, LR=0.000030]
# Epoch 91/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.06batch/s, loss=0.7937, LR=0.000024]
# Epoch 92/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.10batch/s, loss=0.7926, LR=0.000020]
# Epoch 93/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.02batch/s, loss=0.7900, LR=0.000016]
# Epoch 94/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.04batch/s, loss=0.7898, LR=0.000012]
# Epoch 95/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.87batch/s, loss=0.7906, LR=0.000009]
# Epoch 96/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 20.80batch/s, loss=0.7905, LR=0.000006]
# Epoch 97/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.59batch/s, loss=0.7851, LR=0.000004]
# Epoch 98/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 20.15batch/s, loss=0.7877, LR=0.000002]
# Epoch 99/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:16<00:00, 21.38batch/s, loss=0.7896, LR=0.000001]
# Epoch 100/100 (Ablation 2 (No Dropout)): 100%|██████████| 352/352 [00:17<00:00, 19.86batch/s, loss=0.7854, LR=0.000000]
# --- Experiment Finished: Ablation 2 (No Dropout) ---
# Final Test Accuracy for Ablation 2 (No Dropout): 90.13%
#
# --- Starting Experiment: Ablation 3 (No L2 Decay) ---
# Using Strong Data Augmentation (Crop, Flip, AutoAugment)
# Epoch 1/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.45batch/s, loss=1.8070, LR=0.001000]
# Epoch 2/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.49batch/s, loss=1.5253, LR=0.001000]
# Epoch 3/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.62batch/s, loss=1.4238, LR=0.000999]
# Epoch 4/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.41batch/s, loss=1.3632, LR=0.000998]
# Epoch 5/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.03batch/s, loss=1.3193, LR=0.000996]
# Epoch 6/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.05batch/s, loss=1.2803, LR=0.000994]
# Epoch 7/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.87batch/s, loss=1.2545, LR=0.000991]
# Epoch 8/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.48batch/s, loss=1.2243, LR=0.000988]
# Epoch 9/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.60batch/s, loss=1.2003, LR=0.000984]
# Epoch 10/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.30batch/s, loss=1.1870, LR=0.000980]
# Epoch 11/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.08batch/s, loss=1.1633, LR=0.000976]
# Epoch 12/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.38batch/s, loss=1.1533, LR=0.000970]
# Epoch 13/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.85batch/s, loss=1.1290, LR=0.000965]
# Epoch 14/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.16batch/s, loss=1.1181, LR=0.000959]
# Epoch 15/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.43batch/s, loss=1.1046, LR=0.000952]
# Epoch 16/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.76batch/s, loss=1.0892, LR=0.000946]
# Epoch 17/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.42batch/s, loss=1.0821, LR=0.000938]
# Epoch 18/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.96batch/s, loss=1.0722, LR=0.000930]
# Epoch 19/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.05batch/s, loss=1.0597, LR=0.000922]
# Epoch 20/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.51batch/s, loss=1.0502, LR=0.000914]
# Epoch 21/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.55batch/s, loss=1.0399, LR=0.000905]
# Epoch 22/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.98batch/s, loss=1.0297, LR=0.000895]
# Epoch 23/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.81batch/s, loss=1.0211, LR=0.000885]
# Epoch 24/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.53batch/s, loss=1.0155, LR=0.000875]
# Epoch 25/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.76batch/s, loss=1.0117, LR=0.000864]
# Epoch 26/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.49batch/s, loss=1.0017, LR=0.000854]
# Epoch 27/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.49batch/s, loss=0.9942, LR=0.000842]
# Epoch 28/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.83batch/s, loss=0.9903, LR=0.000831]
# Epoch 29/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.35batch/s, loss=0.9823, LR=0.000819]
# Epoch 30/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.87batch/s, loss=0.9739, LR=0.000806]
# Epoch 31/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.64batch/s, loss=0.9706, LR=0.000794]
# Epoch 32/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.47batch/s, loss=0.9667, LR=0.000781]
# Epoch 33/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.08batch/s, loss=0.9603, LR=0.000768]
# Epoch 34/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.12batch/s, loss=0.9539, LR=0.000755]
# Epoch 35/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.52batch/s, loss=0.9507, LR=0.000741]
# Epoch 36/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.67batch/s, loss=0.9457, LR=0.000727]
# Epoch 37/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.64batch/s, loss=0.9380, LR=0.000713]
# Epoch 38/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.81batch/s, loss=0.9300, LR=0.000699]
# Epoch 39/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.56batch/s, loss=0.9276, LR=0.000684]
# Epoch 40/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.28batch/s, loss=0.9226, LR=0.000669]
# Epoch 41/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.13batch/s, loss=0.9191, LR=0.000655]
# Epoch 42/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.80batch/s, loss=0.9193, LR=0.000639]
# Epoch 43/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.15batch/s, loss=0.9130, LR=0.000624]
# Epoch 44/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.60batch/s, loss=0.9035, LR=0.000609]
# Epoch 45/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.64batch/s, loss=0.8992, LR=0.000594]
# Epoch 46/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.65batch/s, loss=0.8989, LR=0.000578]
# Epoch 47/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.01batch/s, loss=0.8963, LR=0.000563]
# Epoch 48/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.85batch/s, loss=0.8881, LR=0.000547]
# Epoch 49/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.60batch/s, loss=0.8885, LR=0.000531]
# Epoch 50/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.10batch/s, loss=0.8841, LR=0.000516]
# Epoch 51/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.09batch/s, loss=0.8811, LR=0.000500]
# Epoch 52/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.67batch/s, loss=0.8748, LR=0.000484]
# Epoch 53/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.14batch/s, loss=0.8709, LR=0.000469]
# Epoch 54/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.29batch/s, loss=0.8679, LR=0.000453]
# Epoch 55/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.51batch/s, loss=0.8666, LR=0.000437]
# Epoch 56/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.42batch/s, loss=0.8628, LR=0.000422]
# Epoch 57/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:15<00:00, 22.09batch/s, loss=0.8622, LR=0.000406]
# Epoch 58/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.08batch/s, loss=0.8576, LR=0.000391]
# Epoch 59/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.37batch/s, loss=0.8530, LR=0.000376]
# Epoch 60/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.82batch/s, loss=0.8498, LR=0.000361]
# Epoch 61/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.25batch/s, loss=0.8533, LR=0.000345]
# Epoch 62/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.46batch/s, loss=0.8438, LR=0.000331]
# Epoch 63/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.72batch/s, loss=0.8417, LR=0.000316]
# Epoch 64/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.70batch/s, loss=0.8401, LR=0.000301]
# Epoch 65/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.95batch/s, loss=0.8367, LR=0.000287]
# Epoch 66/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.51batch/s, loss=0.8353, LR=0.000273]
# Epoch 67/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.45batch/s, loss=0.8316, LR=0.000259]
# Epoch 68/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.91batch/s, loss=0.8278, LR=0.000245]
# Epoch 69/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.91batch/s, loss=0.8305, LR=0.000232]
# Epoch 70/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.61batch/s, loss=0.8285, LR=0.000219]
# Epoch 71/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.56batch/s, loss=0.8184, LR=0.000206]
# Epoch 72/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.87batch/s, loss=0.8191, LR=0.000194]
# Epoch 73/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.61batch/s, loss=0.8210, LR=0.000181]
# Epoch 74/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.97batch/s, loss=0.8154, LR=0.000169]
# Epoch 75/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.04batch/s, loss=0.8136, LR=0.000158]
# Epoch 76/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.38batch/s, loss=0.8153, LR=0.000146]
# Epoch 77/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.62batch/s, loss=0.8147, LR=0.000136]
# Epoch 78/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.08batch/s, loss=0.8065, LR=0.000125]
# Epoch 79/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.39batch/s, loss=0.8089, LR=0.000115]
# Epoch 80/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.83batch/s, loss=0.8063, LR=0.000105]
# Epoch 81/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.44batch/s, loss=0.8057, LR=0.000095]
# Epoch 82/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.57batch/s, loss=0.8098, LR=0.000086]
# Epoch 83/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 20.52batch/s, loss=0.8017, LR=0.000078]
# Epoch 84/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.41batch/s, loss=0.8036, LR=0.000070]
# Epoch 85/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.36batch/s, loss=0.8042, LR=0.000062]
# Epoch 86/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.34batch/s, loss=0.8013, LR=0.000054]
# Epoch 87/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.39batch/s, loss=0.8022, LR=0.000048]
# Epoch 88/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:17<00:00, 19.74batch/s, loss=0.8000, LR=0.000041]
# Epoch 89/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.73batch/s, loss=0.7981, LR=0.000035]
# Epoch 90/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.40batch/s, loss=0.7982, LR=0.000030]
# Epoch 91/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.71batch/s, loss=0.7984, LR=0.000024]
# Epoch 92/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.05batch/s, loss=0.7976, LR=0.000020]
# Epoch 93/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.63batch/s, loss=0.7973, LR=0.000016]
# Epoch 94/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.33batch/s, loss=0.7929, LR=0.000012]
# Epoch 95/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.71batch/s, loss=0.7953, LR=0.000009]
# Epoch 96/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.94batch/s, loss=0.7923, LR=0.000006]
# Epoch 97/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.44batch/s, loss=0.7967, LR=0.000004]
# Epoch 98/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.82batch/s, loss=0.7921, LR=0.000002]
# Epoch 99/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 20.94batch/s, loss=0.7943, LR=0.000001]
# Epoch 100/100 (Ablation 3 (No L2 Decay)): 100%|██████████| 352/352 [00:16<00:00, 21.62batch/s, loss=0.7980, LR=0.000000]
# --- Experiment Finished: Ablation 3 (No L2 Decay) ---
# Final Test Accuracy for Ablation 3 (No L2 Decay): 90.33%
#
#
# ======================================================================
# FINAL EXPERIMENTAL RESULTS SUMMARY FOR PROJECT REPORT
# ======================================================================
#
#
# --- Table 1: Quantitative Comparison (Baseline) ---
# Model                               Test Acc. (%)   Type
# -----------------------------------------------------------------
# SimpleCNN (Main/Full)               90.31           Custom CNN (Ours)
#
#
# --- Table 2: Ablation Study (3 Groups on SimpleCNN) ---
# Experiment                          Configuration        Test Acc. (%)
# ----------------------------------------------------------------------
# Main Model (Best)                   Full Features        90.31
# Ablation 1 (No Augmentation)        No No Augmentation   80.81
# Ablation 2 (No Dropout)             No No Dropout        90.13
# Ablation 3 (No L2 Decay)            No No L2 Decay       90.33
#
# All required experiments are complete.
# Master execution function defined. Run this cell to start all 5 experiments.
